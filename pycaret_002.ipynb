# %% [markdown]
# <a href="https://colab.research.google.com/github/cristiandarioortegayubro/P4DA/blob/main/pycaret_002.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![](https://github.com/cristiandarioortegayubro/P4DA/blob/main/Logo.png?raw=true)

# %% [markdown]
# ![logo](https://github.com/cristiandarioortegayubro/BA/blob/main/PyCaret.png?raw=true)

# %% [markdown]
# <font color="#091f60">
# <h2><b>
# Modelo de Regresion con PyCaret
#
# </font>

# %% [markdown]
# ## Instalando las librerías necesarias

# %%
# !pip install pycaret
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ## Carga de librerías necesarias

# %% [markdown]
# ### Analisis de datos

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ## Obtención de los Datos

# %%
datos = "https://raw.githubusercontent.com/cristiandarioortegayubro/UNI/main/propiedades.csv"

# %%
df = pd.read_csv(datos)
df.drop(columns="Unnamed: 0", inplace=True)
df
# Out:
#           id         l1               l2             l3  rooms  bedrooms  \
# 0          0  Argentina  Capital Federal        Palermo    2.0       1.0
# 1          1  Argentina  Capital Federal       Belgrano    NaN       NaN
# 2          2  Argentina  Capital Federal      San Telmo    1.0       NaN
# 3          3  Argentina  Capital Federal  Villa Urquiza    2.0       NaN
# 4          4  Argentina  Capital Federal       Belgrano    6.0       4.0
# ...      ...        ...              ...            ...    ...       ...
# 44673  44673  Argentina  Capital Federal   Monte Castro    2.0       1.0
# 44674  44674  Argentina  Capital Federal   Barrio Norte    2.0       1.0
# 44675  44675  Argentina  Capital Federal     Colegiales    2.0       1.0
# 44676  44676  Argentina  Capital Federal     Colegiales    1.0       1.0
# 44677  44677  Argentina  Capital Federal   Villa Crespo    2.0       1.0
#
#        bathrooms  surface_total  surface_covered   price
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44678 entries, 0 to 44677
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               44678 non-null  int64
#  1   l1               44678 non-null  object
#  2   l2               44678 non-null  object
#  3   l3               44382 non-null  object
#  4   rooms            43547 non-null  float64
#  5   bedrooms         38623 non-null  float64
#  6   bathrooms        43371 non-null  float64
#  7   surface_total    39856 non-null  float64
#  8   surface_covered  40641 non-null  float64
#  9   price            44678 non-null  int64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 3.4+ MB

# %% [markdown]
# - l1 - país
# - l2 - provincia o ciudad
# - l3 - barrio
# - rooms - cantidad de habitaciones
# - bedrooms - cantidad de dormitorios
# - bathrooms - cantidad de baños
# - surface_total - superficie total
# - surface_covered - superficie cubierta
# - price - precio

# %% [markdown]
# # Configuración del entorno PyCaret

# %%
from pycaret.regression import *

# %%
regresion = setup(data = df, 
                  target = "price", 
                  session_id=123)
# Out:
# <style type="text/css">
# #T_e1b87_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e1b87" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e1b87_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e1b87_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e1b87_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e1b87_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e1b87_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_e1b87_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e1b87_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e1b87_row1_col1" class="data row1 col1" >price</td>
#     </tr>
#     <tr>
#       <th id="T_e1b87_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %% [markdown]
# # Modelo

# %%
mejor_modelo = compare_models(n_select=3)
# Out:
# <style type="text/css">
# #T_49fd1 th {
#   text-align: left;
# }
# ...

# %%
mejor_modelo
# Out:
# [GradientBoostingRegressor(random_state=123),
#  ExtraTreesRegressor(n_jobs=-1, random_state=123),
#  LinearRegression(n_jobs=-1)]

# %%
predict_model(mejor_modelo[0], data=df)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5a47c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a47c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5a47c_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_5a47c_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_5a47c_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_5a47c_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_5a47c_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_5a47c_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a47c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5a47c_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_5a47c_row0_col1" class="data row0 col1" >59215.7095</td>
# ...
