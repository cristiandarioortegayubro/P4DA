# %% [markdown]
# <a href="https://colab.research.google.com/github/cristiandarioortegayubro/P4DA/blob/main/Ejercitaci%C3%B3n_adicional_Python_001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![](https://github.com/cristiandarioortegayubro/P4DA/blob/main/Logo.png?raw=true)

# %% [markdown]
# ##Ejercitación Adicional - Python
#
# La idea con los siguientes ejercicios es practicar lo aprendido hasta el momento en Python más allá de un marco de análisis de DataFrames o el uso de Pandas.
#
# Vale aclarar que no hay una forma única ni ***correcta*** de resolverlos, el objetivo es responder la necesidad. Una vez resuelta, sí puede tomar mayor importancia las formas y la eficiencia de la solución propuesta.

# %% [markdown]
# ##1. Matemática

# %% [markdown]
# ###1.1 🔥 Números primos

# %% [markdown]
# Generar un script o función que permita obtener todos los números primos hasta cierto número ingresado por el usuario.
#
# Esto puede ser: "quiero los primero **n** primos" o "quiero todos los primos hasta el número **n**". Cualquiera de esas dos soluciones es correcta.

# %% [markdown]
# ###1.2 🔥 Números coprimos

# %% [markdown]
# Generar un script o función que permita determinar si dos números son coprimos.
#
# Dos números son coprimos cuando no tienen divisores comunes entre sí (excluyendo al 1). Por ejemplo: 15 y el 16, los divisores de 15 son d(15) = 1, 3, 5; los divisores de 16 son d(16) = 1, 2, 4, 8. Por lo tanto, 15 y 16 son coprimos.

# %% [markdown]
# ###1.3 🔥 Figuras geométricas

# %% [markdown]
# Generar un script o función que permita calcular el área de un polígono regular, ingresando como parámetro la cantidad de lados y la medida de uno de esos lados.

# %% [markdown]
# ####1.3b 🔥🔥 Figuras geométricas

# %% [markdown]
# Para todo polígono regular se pueden definir dos circunferencias:
# - Una exterior que circunscribe al polígono.
# - Una interior que se encuentra inscrita dentro del polígono.
# ![image.png](data:image/png;base64,...)
#
#
# Para un dado polígono, esto genera dos áreas. En verde se ve la diferencia entre el círculo mayor y el polígono, mientras que en rojo se marca la diferencia entre el polígono y el círculo interior.
#
# ![image.png](data:image/png;base64,...)
#
# **Se pide calcular el porcentaje que representan estas dos áreas sobre la superficie total del polígono de cualquier cantidad de lados ingresado como parámetro, suponiendo que la medida de cada lado es 1cm.**
#
# Por ejemplo, para un triángulo de lado 1 cm:
# ![image.png](data:image/png;base64,...)
#
# Área triángulo = 0.433 cm<sup>2</sup>
#
# Área verde = 0.614 cm<sup>2</sup>
#
# Área roja = 0.262 cm<sup>2</sup>
#
#
# %Area verde = 141.6% del triángulo
#
# %Area roja = 39.4% del triángulo

# %% [markdown]
# ####1.3c 🔥🔥🔥 Figuras geométricas

# %% [markdown]
# Se puede apreciar que a medida que vamos aumentando el número de lados, la diferencia porcentual entre las áreas disminuye, pues todas las figuras convergen a la circunferencia exterior.
#
# - A partir de qué número de lados esta diferencia es menor al 10% en ambos casos?
# - Y al 1%?
# - Y al 0.1%?
# - Y si quisiera una función donde especifíco la diferencia porcentual deseada y me devuelve la cantidad de lados mínima que tiene que tener mi polígono?
#
# - Todos estos resultados varían si el polígono tuviera lado = 3cm?

# %% [markdown]
# ##2. Palabras

# %% [markdown]
# ###2.1 🔥 Generar un script o función que permita analizar una frase y determinar cuáles son las 5 letras que más se repiten

# %% [markdown]
# i.e. Si uno ingresara la frase:
#
# "*Beautiful is better than ugly.*
#
# *Explicit is better than implicit.*
#
# *Simple is better than complex.*
#
# *Complex is better than complicated.*
#
# *Flat is better than nested.*
#
# *Sparse is better than dense.*
#
# *Readability counts.*
#
# *Special cases aren't special enough to break the rules.*
#
# *Although practicality beats purity.*
#
# *Errors should never pass silently.*
#
# *Unless explicitly silenced.*
#
# *In the face of ambiguity, refuse the temptation to guess.*
#
# *There should be one– and preferably only one –obvious way to do it.*
#
# *Although that way may not be obvious at first unless you're Dutch.*
#
# *Now is better than never.*
#
# *Although never is often better than right now.*
#
# *If the implementation is hard to explain, it's a bad idea.*
#
# *If the implementation is easy to explain, it may be a good idea.*
#
# *Namespaces are one honking great idea – let's do more of those!"*
#
#
# La respuesta debería ser:
#
# ```
# Las 5 letras que más repiten en su frase son:
#
# "e": 86 veces.
#
# "t": 74 veces.
#
# "a": 50 veces.
#
# "i": 49 veces.
#
# "s": 42 veces.
# ```

# %% [markdown]
# ###2.1b 🔥 Modificar el script/función anterior para que devuelva las **n** letras más repetidas.

# %% [markdown]
# A su vez, se quiere hacer un histograma de todas las letras para ver su distribución, las letras más preponderantes de la frase y su contribución porcentual.

# %% [markdown]
# ##3. Biología

# %% [markdown]
# ###3.1 🔥 Traducción del ARN.

# %% [markdown]
# Usted trabaja en una industria de síntesis proteica con fines medicinales.
# Para esto, se toman templates de ARN animal y se lo traduce a proteinas utilizando una tabla de conversión conocida como el "código genético universal".
#
# ![MGA2-03-28.jpg](data:image/jpeg;base64,...)
#
# El ARN se analiza como una secuencia de bases donde cada codón (grupo de 3 bases) codifica para un aminoácido en particular. Dentro del ribosoma se lee el ARN codón a codón y se enlazan los aminoácidos correspondientes, formando así la proteina (que no es otra cosa más que un conjunto de aminoácidos ordenados y plegados de alguna forma particular).
#
# ![Ribosomes.jpg](data:image/jpeg;base64,...)
#
# Por ejemplo:
#
# Si se tuviera la secuencia "**AAGCUAUCGGUA**", usando el código genético universal, esto codificaría para: *Lys-Leu-Ser-Val*.
#
# Donde:
#
# **AAG:** Lys
#
# **CUA:** Leu
#
# **UCG:** Ser
#
# **GUA:** Val
#
# El requerimiento de la industria es generar un script/función que sea capaz de traducir cualquier string de ARN expresado en codones (ternas de 3 bases cada uno i.e. **"CGAUUGGCAAGUCGA"**) a su correspondiente cadena de aminoácidos.

# %% [markdown]
# ###3.1b 🔥🔥 Traducción del ARN.

# %% [markdown]
# Modifique la función anterior para que sea capaz de reconocer los codones de START y STOP presentes en el ARN.
#
# Esto significa que la cadena de strings puede empezar con cualquier cantidad de pares de base que no aportarán información hasta llegar a un codón START (**AUG**) que a su vez codifica para metionina -por esta razón **todas** las proteinas tienen una metionina en su extremo- y dejará de traducir cuando se encuentre con codones STOP (**UAA, UAG y UGA**), independientemente de la longitud del string.
#
# Al mismo tiempo, es necesario ampliar el funcionamiento para que reconozca y traduzca moléculas de ADN. *(La diferencia entre ADN y ARN es la presencia de timina (T) en la cadena en lugar del uracilo (U))*

# %% [markdown]
# ###3.1c 🔥🔥🔥 Análisis de ADN viral

# %% [markdown]
# En el NIH de Estados Unidos se pueden encontrar varias tablas con datos interesantes de ADN, una de ellas refiere a las cadenas de ADN viral para más de 1800 especies
#
# https://www.ncbi.nlm.nih.gov/labs/virus/vssi/#/
#
# Descargar esta tabla, realizar la limpieza de datos que considere necesario y aplicar las funciones generadas para la traducción del ARN a proteinas.
#
# Finalmente hacer un análisis de los resultados:
# - ¿La distribución de aminoácidos es uniforme?
# - ¿Cuál es la longitud de proteina promedio?
# - Según estos datos, ¿qué aminoácidos considera usted son más importantes para la estructura proteica?
# - ¿Cómo es la relación longitud proteica vs codones en ADN? ¿Considera que se perdió información? ¿Cómo podría corregir esto?

# %% [markdown]
# ##4.  Química

# %% [markdown]
# ### 🔥 4.1 Tabla periódica

# %% [markdown]
# Una escuela del distrito nos pide generar una función que comprenda una tabla períodica computarizada.
# ![fe.png](data:image/png;base64,...)
#
# Para esto, los alumnos deberían tener la posibilidad de ingresar un número como parámetro al llamar la función y ésta devolvería:
#
# - El elemento en cuestión (Nombre y siglas)
# - El peso atómico promedio
# - Su electronegatividad
# - Sus estados de oxidación
# - Cualquier otra información que considere relevante
#
# *(Teniendo en cuenta que hoy en día hay 118 elementos, se acepta un prototipo modelo con solamente algunos valores para luego expandir el trabajo)*

# %% [markdown]
# #### 🔥🔥 4.1.b Tabla periódica

# %% [markdown]
# La iniciativa fue un éxito, pero ahora nos comunican los nuevos requerimientos de los alumnos:
# ![tabla.png](data:image/png;base64,...)
# - Se debe informar a qué grupo pertenece el elemento.
# - Se debe informar a qué período pertenece el elemento.
# - Se debe informar a qué categoría pertenecen (Metales alcalinos, metales alcalino-térreos, no metales, gases nobles, etc.)

# %% [markdown]
# ### 🔥 4.2 Clasificación de Petroleo

# %% [markdown]
# Hay diversas formas de diferenciar al petroleo, desde su origen, composición química, densidad, gravedad API, etc.
#
# En este caso particular, la empresa para la cual estamos contratados posee una base de datos que informa la densidad del crudo (expresada como kg/m<sup>3</sup>) pero quiere catalogarla según el grado API donde:
#
# *Crudo liviano*: **API > 31.1°**
#
# *Crudo mediano*: **22.3° < API < 31.1°**
#
# *Crudo pesado*: **10° < API < 22.3°**
#
# *Crudo extrapesado*: **API < 10°**
#
# Usted sabe que el cálculo de gravedad API es el siguiente:
#
# ![image.png](data:image/png;base64,...)
#
# Donde GE se refuere a la gravedad específica y no es otra cosa más que la densidad relativa del fluido referida al agua:
#
# ![image.png](data:image/png;base64,...)  ,   donde image.png es la densidad del agua a 1 atm y 4°C (definida como 1kg/m<sup>3</sup>.)
#
#
#
# De esta forma, se debe generar un script/función donde se ingrese un valor de densidad de crudo y se devuelva su correspondiente gravedad API, indicando a que categoría pertenece.
#
# *Aplicar el código a un dataframe generado con el diccionario "datos_crudo", teniendo en cuenta que se trata de una tabla con valores reales medidos por sensor*

# %%
datos_crudo = {
    'pozo': ['PPE-707','PLD-892','AAB-132','HTG-819','A-866','GH-65','PLD-402','AG-687','PKI-401','PLD-657',
 'AAB-946','PLD-903','OOF-884','PKI-303','PLD-432','AAB-531','PLD-798','A-506','AAB-56','PKI-574','OOF-827',
 'C-867','OOF-911','C-411','AAB-959','GH-860','C-620','PPE-182','C-285','PLD-629','PLD-203','AG-904','AG-66',
 'AAB-333','GH-390','PPE-45','GH-660','PKI-376','OOF-614','AAB-694','PPE-141','OOF-169','C-674','OOF-880',
 'OOF-204','HTG-568','OOF-83','HTG-51','OOF-330','PPE-421','A-250','A-815','PPE-937','GH-382','PLD-787',
 'OOF-517','OOF-202','AAB-525','C-553','PPE-265','PPE-284','PKI-761','PKI-461','AAB-575','HTG-271','HTG-103',
 'GH-798','PKI-679','HTG-448','GH-75','AAB-392','HTG-916','HTG-880','C-109','PPE-460','PKI-585','PPE-132',
 'HTG-859','OOF-398','OOF-240','A-730','C-175','C-401','PLD-638','HTG-132','C-784','GH-818','AAB-955','PKI-776',
 'OOF-750','GH-314','OOF-102','PPE-290','HTG-291','PPE-23','HTG-711','AAB-520','PPE-233','PLD-829','PPE-568'],
    'densidad': [0.688, 0.858,0.641,0.772,0.977,0.784,0.783,0.645,0.765,0.968,0.838,0.941,
 0.815,0.402,0.5,0.954,0.667,0.629,0.909,1.0,0.49,0.513,0.934,0.721,0.909,0.934,0.594,0.457,
 0.981,0.93,0.671,0.659,0.942,0.897,0.851,0.888,0.669,0.84,0.884,0.485,0.739,0.663,0.656,0.659,
 0.763,0.754, 0.938, 0.531,0.894,0.733,0.775,0.949,0.88,0.956,0.809,0.751,0.936,0.639,0.829,
 0.978,0.779,0.62,0.68,0.765,0.976,0.866,0.647,0.881,0.499,0.899,0.589,0.724, 0.56,0.688,0.808,
 0.61,0.438,0.479,0.614,0.508,0.674,0.815,0.916,0.974,0.604,0.676,0.836,0.784,0.823,0.856,0.567,
 0.603,0.519,0.906,0.801,0.774,0.6,0.931,0.738,0.935]
}

# %% [markdown]
# ####4.2b 🔥🔥🔥 Clasificación de Petroleo

# %% [markdown]
# Después de analizar los resultados, desde la empresa nos dicen que la categorización no es particularmente efectiva y genera diferencias significativas sobre los datos observados.
#
# Hacer supuestos ideales sobre el cálculo de la densidad no es lo correcto y se requiere refinar la fórmula. Para esto, compraron nuevos sensores en el pozo que permiten medir presión (**P**) y temperatura (**T**). De esta manera, el cálculo de densidad relativa debe considerar alguno de estos datos para la densidad del agua.
#
# Una forma sencilla pero algo tediosa es revisar la tabla de densidades vs Temperatura.
#
# http://www.vaxasoftware.com/doc_edu/qui/denh2o.pdf
# ![image.png](data:image/png;base64,...)
#
#
# Con esta tabla se pueden corregir todas las densidades de agua y con eso las gravedades específicas. Para evitar generar un nuevo diccionario y el trabajo manual de establecer la relación para cada valor de temperatura, se podría buscar una función polinómica que ajuste bien a estos valores,  aplicársela a la columna de Temperaturas y obtener densidad de agua (es decir obtener d(T)).
#
# *(Tener en cuenta las unidades)*
#
# Finalmente, para determinar si fue útil la compra de estos nuevos sensores, se requiere calcular nuevamente las categorías para todos los pozos e informar el porcentaje de diferencias observadas respecto al método anterior. Si las diferencias observadas no superan el 10%, se considerarará que el costo de mantenimiento del instrumental no amerita esta corrección.

# %%
datos_crudo_TyP = {
    'pozo': ['PPE-707','PLD-892','AAB-132','HTG-819','A-866','GH-65','PLD-402','AG-687','PKI-401','PLD-657',
 'AAB-946','PLD-903','OOF-884','PKI-303','PLD-432','AAB-531','PLD-798','A-506','AAB-56','PKI-574','OOF-827',
 'C-867','OOF-911','C-411','AAB-959','GH-860','C-620','PPE-182','C-285','PLD-629','PLD-203','AG-904','AG-66',
 'AAB-333','GH-390','PPE-45','GH-660','PKI-376','OOF-614','AAB-694','PPE-141','OOF-169','C-674','OOF-880',
 'OOF-204','HTG-568','OOF-83','HTG-51','OOF-330','PPE-421','A-250','A-815','PPE-937','GH-382','PLD-787',
 'OOF-517','OOF-202','AAB-525','C-553','PPE-265','PPE-284','PKI-761','PKI-461','AAB-575','HTG-271','HTG-103',
 'GH-798','PKI-679','HTG-448','GH-75','AAB-392','HTG-916','HTG-880','C-109','PPE-460','PKI-585','PPE-132',
 'HTG-859','OOF-398','OOF-240','A-730','C-175','C-401','PLD-638','HTG-132','C-784','GH-818','AAB-955','PKI-776',
 'OOF-750','GH-314','OOF-102','PPE-290','HTG-291','PPE-23','HTG-711','AAB-520','PPE-233','PLD-829','PPE-568'],
 'profundidad (mts)': [335,1413,2138,2100,536,2105,380,1689,2449,460,1311,356,794,1114,1301,2416,1266,474,405,
 2345,2130,1038,708,2072,1384,802,789,1356,2311,1795,1709,859,1593,770,2484,1828,1500,1957,1773,370,1056,1020,
 1840,499,2368,1120,1062,562,316,2388,1915,757,1688,1716,2227,1657,686,2494,902,2020,2003,879,1055,1617,829,
 1376,1124,1593,1400,1855,1970,308,1130,1395,1951,2360,1976,1396,1230,853,2116,729,2174,1932,1846,
 515,662,533,1325,1696,1422,1101,1651,1845,2402,2498,754,1741,2258,1947],
 'temperatura (°C)': [64.3,16.4,35.1,42.0,61.4,22.8,58.4,18.9,36.3,37.6,36.7,39.6,52.5,22.3,21.4,59.4,
 25.8,47.5,39.6,62.0,63.1,24.9,49.5,60.4,38.2,58.4,34.6,64.3,50.9,60.4,29.4,38.6,19.8,59.4,74.6,56.3,
 19.2,43.1,53.2,53.5,19.9,51.5,20.6,43.6,41.7,62.4,23.8,49.5,40.6,67.9,24.5,55.4,29.1,33.0,70.4,49.5,
 47.5, 49.9,44.5,37.2,56.9,45.5,24.9,53.1,43.6,31.9,16.2,40.6,45.5,50.5,61.5,39.6,53.5,22.3,23.4,56.4,29.3,
 29.6,14.3,62.4,37.3,52.5,65.3,64.2,47.5,56.4,55.4,41.6,43.5,32.6,59.4,14.1,20.5,39.9,29.8,37.0,24.1,20.9,32.5,49.1],
}
