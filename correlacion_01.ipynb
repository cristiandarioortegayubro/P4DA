# %% [markdown]
# <a href="https://colab.research.google.com/github/cristiandarioortegayubro/P4DA/blob/main/correlacion_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![](https://github.com/cristiandarioortegayubro/P4DA/blob/main/Logo.png?raw=true)

# %% [markdown]
# # **<font color="RoyalBlue">Análisis Exploratorio de los Datos - Matriz de Correlación**

# %% [markdown]
# # **<font color="RoyalBlue">Carga de módulos**

# %% [markdown]
# ### **<font color="RoyalBlue">Para analisis de datos**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### **<font color="RoyalBlue">Para graficos**

# %%
import plotly.express as px

# %% [markdown]
# ## **<font color="RoyalBlue">Carga de Datos**

# %% [markdown]
# ***Antes que nada, se genera el dataframe con los datos que se utilizaran para la matriz de correlación...***

# %%
url = "https://raw.githubusercontent.com/cristiandarioortegayubro/BA/main/Datasets/recursos_humanos_II.csv"

# %%
analisis = pd.read_csv(url)
analisis.drop(columns="Unnamed: 0", inplace=True)
analisis.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# 4     low

# %% [markdown]
# ***Se cambian los nombres de las columnas para mejor interpretacion...***

# %%
analisis.rename(columns={"satisfaction_level":"niveldesatisfaccion",
                         "last_evaluation":"ultimaevaluacion",
                         "number_project":"numerosdeproyectos",
                         "average_montly_hours":"horasmensualespromedio",
                         "time_spend_company":"tiempoenlaempresa",
                         "Work_accident":"accidentedetrabajo",
                         "left":"abandono",
                         "promotion_last_5years":"promocionultimos5años",
                         "sales":"ventas",
                         "salary":"sueldo"}, inplace= True)

# %% [markdown]
# # **<font color="RoyalBlue">Matriz de correlación**

# %% [markdown]
# ***La correlación estadística constituye una técnica estadística que  indica si las variables están relacionadas o no lo están.***

# %% [markdown]
# ***Por ejemplo, en las variables del ingreso familiar y el gasto familiar se sabe que un aumento en los ingresos genera un aumento en los gastos, y una disminución de los ingresos, genera una disminución de los gastos. Por lo tanto, las variables ingresos y gastos están relacionadas y un cambio en cualquiera de esas variables estará acompañado por un cambio en la otra variable en el mismo sentido, o con el mismo signo.***

# %% [markdown]
# ***De la misma manera, los precios y la demanda de un producto son variables relacionadas; cuando los precios aumentan la demanda tenderá a disminuir y viceversa.***

# %% [markdown]
# ***En el caso del ingreso familiar y el gasto familiar, es fácil ver que ambos suben o bajan juntos en la misma dirección. Esto se denomina correlación positiva.***

# %% [markdown]
# ***En caso del precio y la demanda, el cambio se produce en la dirección opuesta, de modo que el aumento de una variables está acompañado de una disminución en la otra variable. Esto se conoce como correlación negativa.***

# %% [markdown]
# ## **<font color="RoyalBlue">Matriz de correlación** - Coeficiente estándar = método Pearson

# %% [markdown]
# ***La correlación de Pearson funciona bien con variables cuantitativas que tienen una distribución normal o próxima a la normal. Es más sensible a los valores extremos que las otras dos alternativas, Spearman y Kendall.***

# %% [markdown]
# ***La correlación de Spearman se emplea con variables cuantitativas (continuas o discretas). En lugar de utilizar directamente el valor de cada variable, los datos son ordenados y reemplazados por su respectivo orden ranking. Es un método no paramétrico muy utilizado cuando no se satisface la condición de normalidad necesaria para aplicar la correlación de Pearson.***

# %% [markdown]
# ***La correlación de Kendall es otra alternativa no paramétrica que, al igual que la correlación de Spearman, utiliza la ordenación de las observaciones ranking. Es recomendable cuando se dispone de pocos datos.***

# %%
pearson = analisis.corr(method="pearson").round(2)

# %%
pearson
# Out:
#                         niveldesatisfaccion  ultimaevaluacion  \
# niveldesatisfaccion                    1.00              0.11
# ultimaevaluacion                       0.11              1.00
# numerosdeproyectos                    -0.14              0.35
# horasmensualespromedio                -0.02              0.34
# tiempoenlaempresa                     -0.10              0.13
# accidentedetrabajo                     0.06             -0.01
# abandono                              -0.39              0.01
# promocionultimos5años                  0.03             -0.01
#
#                         numerosdeproyectos  horasmensualespromedio  \
# niveldesatisfaccion                  -0.14                   -0.02
# ultimaevaluacion                      0.35                    0.34
# numerosdeproyectos                    1.00                    0.42
# horasmensualespromedio                0.42                    1.00
# tiempoenlaempresa                     0.20                    0.13
# accidentedetrabajo                   -0.00                   -0.01
# abandono                              0.02                    0.07
# promocionultimos5años                -0.01                   -0.00
#
#                         tiempoenlaempresa  accidentedetrabajo  abandono  \
# niveldesatisfaccion                 -0.10                0.06     -0.39
# ultimaevaluacion                     0.13               -0.01      0.01
# numerosdeproyectos                   0.20               -0.00      0.02
# horasmensualespromedio               0.13               -0.01      0.07
# tiempoenlaempresa                    1.00                0.00      0.14
# accidentedetrabajo                   0.00                1.00     -0.15
# abandono                             0.14               -0.15      1.00
# promocionultimos5años                0.07                0.04     -0.06
#
#                         promocionultimos5años
# niveldesatisfaccion                      0.03
# ultimaevaluacion                        -0.01
# numerosdeproyectos                      -0.01
# horasmensualespromedio                  -0.00
# tiempoenlaempresa                        0.07
# accidentedetrabajo                       0.04
# abandono                                -0.06
# promocionultimos5años                    1.00

# %%
px.imshow(pearson,
          title = "Matriz de correlacion",
          text_auto = True, 
          template = "seaborn",
          labels={"color":"Coeficiente"})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a7cdd0b3-0f1a-47f6-a151-5b3ce04dcb84" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a7cdd0b3-0f1a-47f6-a151-5b3ce04dcb84")) {                    Plotly.newPlot(                        "a7cdd0b3-0f1a-47f6-a151-5b3ce04dcb84",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","x":["niveldesatisfaccion","ultimaevaluacion","numerosdeproyectos","horasmensualespromedio","tiempoenlaempresa","accidentedetrabajo","abandono","promocionultimos5a\u00f1os"],"y":["niveldesatisfaccion","ultimaevaluacion","numerosdeproyectos","horasmensualespromedio","tiempoenlaempresa","accidentedetrabajo","abandono","promocionultimos5a\u00f1os"],"z":[[1.0,0.11,-0.14,-0.02,-0.1,0.06,-0.39,0.03],[0.11,1.0,0.35,0.34,0.13,-0.01,0.01,-0.01],[-0.14,0.35,1.0,0.42,0.2,-0.0,0.02,-0.01],[-0.02,0.34,0.42,1.0,0.13,-0.01,0.07,-0.0],[-0.1,0.13,0.2,0.13,1.0,0.0,0.14,0.07],[0.06,-0.01,-0.0,-0.01,0.0,1.0,-0.15,0.04],[-0.39,0.01,0.02,0.07,0.14,-0.15,1.0,-0.06],[0.03,-0.01,-0.01,-0.0,0.07,0.04,-0.06,1.0]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}<br>y: %{y}<br>Coeficiente: %{z}<extra></extra>"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(234,234,242)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"rgb(234,234,242)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"colorscale":[[0.0,"rgb(2,4,25)"],[0.06274509803921569,"rgb(24,15,41)"],[0.12549019607843137,"rgb(47,23,57)"],[0.18823529411764706,"rgb(71,28,72)"],[0.25098039215686274,"rgb(97,30,82)"],[0.3137254901960784,"rgb(123,30,89)"],[0.3764705882352941,"rgb(150,27,91)"],[0.4392156862745098,"rgb(177,22,88)"],[0.5019607843137255,"rgb(203,26,79)"],[0.5647058823529412,"rgb(223,47,67)"],[0.6274509803921569,"rgb(236,76,61)"],[0.6901960784313725,"rgb(242,107,73)"],[0.7529411764705882,"rgb(244,135,95)"],[0.8156862745098039,"rgb(245,162,122)"],[0.8784313725490196,"rgb(246,188,153)"],[0.9411764705882353,"rgb(247,212,187)"],[1.0,"rgb(250,234,220)"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"colorscale":[[0.0,"rgb(2,4,25)"],[0.06274509803921569,"rgb(24,15,41)"],[0.12549019607843137,"rgb(47,23,57)"],[0.18823529411764706,"rgb(71,28,72)"],[0.25098039215686274,"rgb(97,30,82)"],[0.3137254901960784,"rgb(123,30,89)"],[0.3764705882352941,"rgb(150,27,91)"],[0.4392156862745098,"rgb(177,22,88)"],[0.5019607843137255,"rgb(203,26,79)"],[0.5647058823529412,"rgb(223,47,67)"],[0.6274509803921569,"rgb(236,76,61)"],[0.6901960784313725,"rgb(242,107,73)"],[0.7529411764705882,"rgb(244,135,95)"],[0.8156862745098039,"rgb(245,162,122)"],[0.8784313725490196,"rgb(246,188,153)"],[0.9411764705882353,"rgb(247,212,187)"],[1.0,"rgb(250,234,220)"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth": ...

# %% [markdown]
# ***Un valor positivo grande (cercano a 1) indica una fuerte correlación positiva, es decir, si el valor de una de las variables aumenta, el valor de la otra variable aumenta también.***

# %% [markdown]
# ***Un valor negativo grande (cercano a -1) indica una fuerte correlación negativa, es decir, que el valor de una de las variables disminuye al aumentar el de la otra y viceversa.***

# %% [markdown]
# ***Un valor cercano a 0 (tanto positivo como negativo) indica la ausencia de cualquier correlación entre las dos variables, y por lo tanto esas variables son independientes entre sí.***

# %% [markdown]
# ## **<font color="RoyalBlue">Ordenando los valores de la Matriz de correlación**

# %%
orden = pearson.unstack()

# %%
print(orden)
# Out:
# niveldesatisfaccion    niveldesatisfaccion       1.00
#                        ultimaevaluacion          0.11
#                        numerosdeproyectos       -0.14
#                        horasmensualespromedio   -0.02
#                        tiempoenlaempresa        -0.10
#                                                  ...
# promocionultimos5años  horasmensualespromedio   -0.00
#                        tiempoenlaempresa         0.07
#                        accidentedetrabajo        0.04
#                        abandono                 -0.06
#                        promocionultimos5años     1.00
# Length: 64, dtype: float64

# %%
orden = orden.sort_values()

# %%
print(orden)
# Out:
# abandono                niveldesatisfaccion      -0.39
# niveldesatisfaccion     abandono                 -0.39
# abandono                accidentedetrabajo       -0.15
# accidentedetrabajo      abandono                 -0.15
# niveldesatisfaccion     numerosdeproyectos       -0.14
#                                                   ...
# horasmensualespromedio  horasmensualespromedio    1.00
# numerosdeproyectos      numerosdeproyectos        1.00
# ultimaevaluacion        ultimaevaluacion          1.00
# abandono                abandono                  1.00
# promocionultimos5años   promocionultimos5años     1.00
# Length: 64, dtype: float64

# %% [markdown]
# ### <font color="RoyalBlue">Viendo **los valores negativos**

# %%
negativos = orden[orden < 0]

# %%
print(negativos)
# Out:
# abandono                niveldesatisfaccion      -0.39
# niveldesatisfaccion     abandono                 -0.39
# abandono                accidentedetrabajo       -0.15
# accidentedetrabajo      abandono                 -0.15
# niveldesatisfaccion     numerosdeproyectos       -0.14
# numerosdeproyectos      niveldesatisfaccion      -0.14
# niveldesatisfaccion     tiempoenlaempresa        -0.10
# tiempoenlaempresa       niveldesatisfaccion      -0.10
# abandono                promocionultimos5años    -0.06
# promocionultimos5años   abandono                 -0.06
# niveldesatisfaccion     horasmensualespromedio   -0.02
# horasmensualespromedio  niveldesatisfaccion      -0.02
#                         accidentedetrabajo       -0.01
# promocionultimos5años   numerosdeproyectos       -0.01
# ultimaevaluacion        promocionultimos5años    -0.01
# numerosdeproyectos      promocionultimos5años    -0.01
# ultimaevaluacion        accidentedetrabajo       -0.01
# accidentedetrabajo      ultimaevaluacion         -0.01
#                         horasmensualespromedio   -0.01
# promocionultimos5años   ultimaevaluacion         -0.01
# dtype: float64

# %% [markdown]
# ### <font color="RoyalBlue">Viendo **los valores positivos**

# %% [markdown]
# ***Elegir variables fuertemente relacionadas. Es decir, se filtran las variables cuyos valores de coeficiente de correlación sean mayores de 0,4...***

# %%
positivos = orden[orden > 0.4]

# %%
print(positivos)
# Out:
# numerosdeproyectos      horasmensualespromedio    0.42
# horasmensualespromedio  numerosdeproyectos        0.42
# niveldesatisfaccion     niveldesatisfaccion       1.00
# accidentedetrabajo      accidentedetrabajo        1.00
# tiempoenlaempresa       tiempoenlaempresa         1.00
# horasmensualespromedio  horasmensualespromedio    1.00
# numerosdeproyectos      numerosdeproyectos        1.00
# ultimaevaluacion        ultimaevaluacion          1.00
# abandono                abandono                  1.00
# promocionultimos5años   promocionultimos5años     1.00
# dtype: float64

# %% [markdown]
# ## **<font color="RoyalBlue">Estilo en el DataFrame** - Matriz en Pandas

# %%
pearson
# Out:
#                         niveldesatisfaccion  ultimaevaluacion  \
# niveldesatisfaccion                    1.00              0.11
# ultimaevaluacion                       0.11              1.00
# numerosdeproyectos                    -0.14              0.35
# horasmensualespromedio                -0.02              0.34
# tiempoenlaempresa                     -0.10              0.13
# accidentedetrabajo                     0.06             -0.01
# abandono                              -0.39              0.01
# promocionultimos5años                  0.03             -0.01
#
#                         numerosdeproyectos  horasmensualespromedio  \
# niveldesatisfaccion                  -0.14                   -0.02
# ultimaevaluacion                      0.35                    0.34
# numerosdeproyectos                    1.00                    0.42
# horasmensualespromedio                0.42                    1.00
# tiempoenlaempresa                     0.20                    0.13
# accidentedetrabajo                   -0.00                   -0.01
# abandono                              0.02                    0.07
# promocionultimos5años                -0.01                   -0.00
#
#                         tiempoenlaempresa  accidentedetrabajo  abandono  \
# niveldesatisfaccion                 -0.10                0.06     -0.39
# ultimaevaluacion                     0.13               -0.01      0.01
# numerosdeproyectos                   0.20               -0.00      0.02
# horasmensualespromedio               0.13               -0.01      0.07
# tiempoenlaempresa                    1.00                0.00      0.14
# accidentedetrabajo                   0.00                1.00     -0.15
# abandono                             0.14               -0.15      1.00
# promocionultimos5años                0.07                0.04     -0.06
#
#                         promocionultimos5años
# niveldesatisfaccion                      0.03
# ultimaevaluacion                        -0.01
# numerosdeproyectos                      -0.01
# horasmensualespromedio                  -0.00
# tiempoenlaempresa                        0.07
# accidentedetrabajo                       0.04
# abandono                                -0.06
# promocionultimos5años                    1.00

# %%
pearson.style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_b9718_row0_col0, #T_b9718_row1_col1, #T_b9718_row2_col2, #T_b9718_row3_col3, #T_b9718_row4_col4, #T_b9718_row5_col5, #T_b9718_row6_col6, #T_b9718_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b9718_row0_col1 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_b9718_row0_col2, #T_b9718_row0_col3, #T_b9718_row0_col4, #T_b9718_row0_col6, #T_b9718_row5_col1, #T_b9718_row6_col0, #T_b9718_row6_col5, #T_b9718_row6_col7, #T_b9718_row7_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b9718_row0_col5, #T_b9718_row2_col0 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_b9718_row0_col7 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_b9718_row1_col0 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_b9718_row1_col2, #T_b9718_row2_col3 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_b9718_row1_col3 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_b9718_row1_col4, #T_b9718_row3_col4, #T_b9718_row4_col0 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_b9718_row1_col5, #T_b9718_row3_col5, #T_b9718_row4_col7, #T_b9718_row5_col2 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_b9718_row1_col6 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_b9718_row1_col7, #T_b9718_row2_col7 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_b9718_row2_col1 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_b9718_row2_col4 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_b9718_row2_col5, #T_b9718_row4_col5 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_b9718_row2_col6 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_b9718_row3_col0 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_b9718_row3_col1 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_b9718_row3_col2 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_b9718_row3_col6 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_b9718_row3_col7 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_b9718_row4_col1, #T_b9718_row6_col2 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_b9718_row4_col2 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_b9718_row4_col3 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_b9718_row4_col6 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_b9718_row5_col0 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_b9718_row5_col3 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_b9718_row5_col4 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_b9718_row5_col6 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_b9718_row5_col7 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_b9718_row6_col1, #T_b9718_row7_col3 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_b9718_row6_col3 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_b9718_row6_col4 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_b9718_row7_col0 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_b9718_row7_col2 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_b9718_row7_col4 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_b9718_row7_col5 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_b9718_row7_col6 {
#   background-color: #88abfd;
#   color: #000000;
# }
# </style>
# <table id="T_b9718_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >niveldesatisfaccion</th>
#       <th class="col_heading level0 col1" >ultimaevaluacion</th>
#       <th class="col_heading level0 col2" >numerosdeproyectos</th>
#       <th class="col_heading level0 col3" >horasmensualespromedio</th>
#       <th class="col_heading level0 col4" >tiempoenlaempresa</th>
#       <th class="col_heading level0 col5" >accidentedetrabajo</th>
#       <th class="col_heading level0 col6" >abandono</th>
#       <th class="col_heading level0 col7" >promocionultimos5años</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9718_level0_row0" class="row_heading level0 row0" >niveldesatisfaccion</th>
#       <td id="T_b9718_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_b9718_row0_col1" class="data row0 col1" >0.110000</td>
#       <td id="T_b9718_row0_col2" class="data row0 col2" >-0.140000</td>
#       <td id="T_b9718_row0_col3" class="data row0 col3" >-0.020000</td>
#       <td id="T_b9718_row0_col4" class="data row0 col4" >-0.100000</td>
#       <td id="T_b9718_row0_col5" class="data row0 col5" >0.060000</td>
#       <td id="T_b9718_row0_col6" class="data row0 col6" >-0.390000</td>
#       <td id="T_b9718_row0_col7" class="data row0 col7" >0.030000</td>
#     </tr>
#     <tr>
#       <th id="T_b9718_level0_row1" class="row_heading level0 row1" >ultimaevaluacion</th>
#       <td id="T_b9718_row1_col0" class="data row1 col0" >0.110000</td>
#       <td id="T_b9718_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_b9718_row1_col2" class="data row1 col2" >0.350000</td>
#       <td id="T_b9718_row1_col3" class="data row1 col3" >0.340000</td>
#       <td id="T_b9718_row1_col4" class="data row1 col4" >0.130000</td>
#       <td id="T_b9718_row1_col5" class="data row1 col5" >-0.010000</td>
#       <td id="T_b9718_row1_col6" class="data row1 col6" >0.010000</td>
#       <td id="T_b9718_row1_col7" class="data row1 col7" >-0.010000</td>
#     </tr>
#     <tr>
#       <th id="T_b9718_level0_row2" class="row_heading level0 row2" >numerosdeproyectos</th>
#       <td id="T_b9718_row2_col0" class="data row2 col0" >-0.140000</td>
#       <td id="T_b9718_row2_col1" class="data row2 col1" >0.350000</td>
#       <td id="T_b9718_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_b9718_row2_col3" class="data row2 col3" >0.420000</td>
#       <td id="T_b9718_row2_col4" class="data row2 col4" >0.200000</td>
#       <td id="T_b9718_row2_col5" class="data row2 col5" >-0.000000</td>
#       <td id="T_b9718_row2_col6" class="data row2 col6" >0.020000</td>
#       <td id="T_b9718_row2_col7" class="data row2 col7" >-0.010000</td>
#     </tr>
#     <tr>
#       <th id="T_b9718_level0_row3" class="row_heading level0 row3" >horasmensualespromedio</th>
#       <td id="T_b9718_row3_col0" class="data row3 col0" >-0.020000</td>
#       <td id="T_b9718_row3_col1" class="data row3 col1" >0.340000</td>
#       <td id="T_b9718_row3_col2" class="data row3 col2" >0.420000</td>
#       <td id="T_b9718_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_b9718_row3_col4" class="data row3 col4" >0.130000</td>
#       <td id="T_b9718_row3_col5" class="data row3 col5" >-0.010000</td>
#       <td id="T_b9718_row3_col6" class="data row3 col6" >0.070000</td>
#       <td id="T_b9718_row3_col7" class="data row3 col7" >-0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b9718_level0_row4" class="row_heading level0 row4" >tiempoenlaempresa</th>
#       <td id="T_b9718_row4_col0" class="data row4 col0" >-0.100000</td>
#       <td id="T_b9718_row4_col1" class="data row4 col1" >0.130000</td>
#       <td id="T_b9718_row4_col2" class="data row4 col2" >0.200000</td>
#       <td id="T_b9718_row4_col3" class="data row4 col3" >0.130000</td>
#       <td id="T_b9718_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_b9718_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_b9718_row4_col6" class="data row4 col6" >0.140000</td>
#       <td id="T_b9718_row4_col7" class="data row4 col7" >0.070000</td>
#     </tr>
#     <tr>
#       <th id="T_b9718_level0_row5" class="row_heading level0 row5" >accidentedetrabajo</th>
#       <td id="T_b9718_row5_col0" class="data row5 col0" >0.060000</td>
#       <td id="T_b9718_row5_col1" class="data row5 col1" >-0.010000</td>
#       <td id="T_b9718_row5_col2" class="data row5 col2" >-0.000000</td>
#       <td id="T_b9718_row5_col3" class="data row5 col3" >-0.010000</td>
#       <td id="T_b9718_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_b9718_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_b9718_row5_col6" class="data row5 col6" >-0.150000</td>
#       <td id="T_b9718_row5_col7" class="data row5 col7" >0.040000</td>
#     </tr>
#     <tr>
#       <th id="T_b971

# %%
pearson.style.background_gradient(cmap="plasma")
# Out:
# <style type="text/css">
# #T_5dc70_row0_col0, #T_5dc70_row1_col1, #T_5dc70_row2_col2, #T_5dc70_row3_col3, #T_5dc70_row4_col4, #T_5dc70_row5_col5, #T_5dc70_row6_col6, #T_5dc70_row7_col7 {
#   background-color: #f0f921;
#   color: #000000;
# }
# #T_5dc70_row0_col1 {
#   background-color: #4903a0;
#   color: #f1f1f1;
# }
# #T_5dc70_row0_col2, #T_5dc70_row0_col3, #T_5dc70_row0_col4, #T_5dc70_row0_col6, #T_5dc70_row5_col1, #T_5dc70_row6_col0, #T_5dc70_row6_col5, #T_5dc70_row6_col7, #T_5dc70_row7_col1 {
#   background-color: #0d0887;
#   color: #f1f1f1;
# }
# #T_5dc70_row0_col5, #T_5dc70_row2_col0 {
#   background-color: #6300a7;
#   color: #f1f1f1;
# }
# #T_5dc70_row0_col7 {
#   background-color: #3a049a;
#   color: #f1f1f1;
# }
# #T_5dc70_row1_col0 {
#   background-color: #a51f99;
#   color: #f1f1f1;
# }
# #T_5dc70_row1_col2, #T_5dc70_row2_col3 {
#   background-color: #ba3388;
#   color: #f1f1f1;
# }
# #T_5dc70_row1_col3 {
#   background-color: #a21d9a;
#   color: #f1f1f1;
# }
# #T_5dc70_row1_col4, #T_5dc70_row3_col4, #T_5dc70_row4_col0 {
#   background-color: #6e00a8;
#   color: #f1f1f1;
# }
# #T_5dc70_row1_col5, #T_5dc70_row3_col5, #T_5dc70_row4_col7, #T_5dc70_row5_col2 {
#   background-color: #4b03a1;
#   color: #f1f1f1;
# }
# #T_5dc70_row1_col6 {
#   background-color: #8b0aa5;
#   color: #f1f1f1;
# }
# #T_5dc70_row1_col7, #T_5dc70_row2_col7 {
#   background-color: #2a0593;
#   color: #f1f1f1;
# }
# #T_5dc70_row2_col1 {
#   background-color: #a31e9a;
#   color: #f1f1f1;
# }
# #T_5dc70_row2_col4 {
#   background-color: #8606a6;
#   color: #f1f1f1;
# }
# #T_5dc70_row2_col5, #T_5dc70_row4_col5 {
#   background-color: #4e02a2;
#   color: #f1f1f1;
# }
# #T_5dc70_row2_col6 {
#   background-color: #8e0ca4;
#   color: #f1f1f1;
# }
# #T_5dc70_row3_col0 {
#   background-color: #8405a7;
#   color: #f1f1f1;
# }
# #T_5dc70_row3_col1 {
#   background-color: #a01a9c;
#   color: #f1f1f1;
# }
# #T_5dc70_row3_col2 {
#   background-color: #c9447a;
#   color: #f1f1f1;
# }
# #T_5dc70_row3_col6 {
#   background-color: #9a169f;
#   color: #f1f1f1;
# }
# #T_5dc70_row3_col7 {
#   background-color: #2e0595;
#   color: #f1f1f1;
# }
# #T_5dc70_row4_col1, #T_5dc70_row6_col2 {
#   background-color: #5102a3;
#   color: #f1f1f1;
# }
# #T_5dc70_row4_col2 {
#   background-color: #8f0da4;
#   color: #f1f1f1;
# }
# #T_5dc70_row4_col3 {
#   background-color: #5502a4;
#   color: #f1f1f1;
# }
# #T_5dc70_row4_col6 {
#   background-color: #ab2494;
#   color: #f1f1f1;
# }
# #T_5dc70_row5_col0 {
#   background-color: #9814a0;
#   color: #f1f1f1;
# }
# #T_5dc70_row5_col3 {
#   background-color: #130789;
#   color: #f1f1f1;
# }
# #T_5dc70_row5_col4 {
#   background-color: #3e049c;
#   color: #f1f1f1;
# }
# #T_5dc70_row5_col6 {
#   background-color: #6001a6;
#   color: #f1f1f1;
# }
# #T_5dc70_row5_col7 {
#   background-color: #3f049c;
#   color: #f1f1f1;
# }
# #T_5dc70_row6_col1, #T_5dc70_row7_col3 {
#   background-color: #1b068d;
#   color: #f1f1f1;
# }
# #T_5dc70_row6_col3 {
#   background-color: #3c049b;
#   color: #f1f1f1;
# }
# #T_5dc70_row6_col4 {
#   background-color: #7100a8;
#   color: #f1f1f1;
# }
# #T_5dc70_row7_col0 {
#   background-color: #910ea3;
#   color: #f1f1f1;
# }
# #T_5dc70_row7_col2 {
#   background-color: #48039f;
#   color: #f1f1f1;
# }
# #T_5dc70_row7_col4 {
#   background-color: #5801a4;
#   color: #f1f1f1;
# }
# #T_5dc70_row7_col5 {
#   background-color: #5c01a6;
#   color: #f1f1f1;
# }
# #T_5dc70_row7_col6 {
#   background-color: #7801a8;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5dc70_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >niveldesatisfaccion</th>
#       <th class="col_heading level0 col1" >ultimaevaluacion</th>
#       <th class="col_heading level0 col2" >numerosdeproyectos</th>
#       <th class="col_heading level0 col3" >horasmensualespromedio</th>
#       <th class="col_heading level0 col4" >tiempoenlaempresa</th>
#       <th class="col_heading level0 col5" >accidentedetrabajo</th>
#       <th class="col_heading level0 col6" >abandono</th>
#       <th class="col_heading level0 col7" >promocionultimos5años</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5dc70_level0_row0" class="row_heading level0 row0" >niveldesatisfaccion</th>
#       <td id="T_5dc70_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_5dc70_row0_col1" class="data row0 col1" >0.110000</td>
#       <td id="T_5dc70_row0_col2" class="data row0 col2" >-0.140000</td>
#       <td id="T_5dc70_row0_col3" class="data row0 col3" >-0.020000</td>
#       <td id="T_5dc70_row0_col4" class="data row0 col4" >-0.100000</td>
#       <td id="T_5dc70_row0_col5" class="data row0 col5" >0.060000</td>
#       <td id="T_5dc70_row0_col6" class="data row0 col6" >-0.390000</td>
#       <td id="T_5dc70_row0_col7" class="data row0 col7" >0.030000</td>
#     </tr>
#     <tr>
#       <th id="T_5dc70_level0_row1" class="row_heading level0 row1" >ultimaevaluacion</th>
#       <td id="T_5dc70_row1_col0" class="data row1 col0" >0.110000</td>
#       <td id="T_5dc70_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_5dc70_row1_col2" class="data row1 col2" >0.350000</td>
#       <td id="T_5dc70_row1_col3" class="data row1 col3" >0.340000</td>
#       <td id="T_5dc70_row1_col4" class="data row1 col4" >0.130000</td>
#       <td id="T_5dc70_row1_col5" class="data row1 col5" >-0.010000</td>
#       <td id="T_5dc70_row1_col6" class="data row1 col6" >0.010000</td>
#       <td id="T_5dc70_row1_col7" class="data row1 col7" >-0.010000</td>
#     </tr>
#     <tr>
#       <th id="T_5dc70_level0_row2" class="row_heading level0 row2" >numerosdeproyectos</th>
#       <td id="T_5dc70_row2_col0" class="data row2 col0" >-0.140000</td>
#       <td id="T_5dc70_row2_col1" class="data row2 col1" >0.350000</td>
#       <td id="T_5dc70_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_5dc70_row2_col3" class="data row2 col3" >0.420000</td>
#       <td id="T_5dc70_row2_col4" class="data row2 col4" >0.200000</td>
#       <td id="T_5dc70_row2_col5" class="data row2 col5" >-0.000000</td>
#       <td id="T_5dc70_row2_col6" class="data row2 col6" >0.020000</td>
#       <td id="T_5dc70_row2_col7" class="data row2 col7" >-0.010000</td>
#     </tr>
#     <tr>
#       <th id="T_5dc70_level0_row3" class="row_heading level0 row3" >horasmensualespromedio</th>
#       <td id="T_5dc70_row3_col0" class="data row3 col0" >-0.020000</td>
#       <td id="T_5dc70_row3_col1" class="data row3 col1" >0.340000</td>
#       <td id="T_5dc70_row3_col2" class="data row3 col2" >0.420000</td>
#       <td id="T_5dc70_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_5dc70_row3_col4" class="data row3 col4" >0.130000</td>
#       <td id="T_5dc70_row3_col5" class="data row3 col5" >-0.010000</td>
#       <td id="T_5dc70_row3_col6" class="data row3 col6" >0.070000</td>
#       <td id="T_5dc70_row3_col7" class="data row3 col7" >-0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5dc70_level0_row4" class="row_heading level0 row4" >tiempoenlaempresa</th>
#       <td id="T_5dc70_row4_col0" class="data row4 col0" >-0.100000</td>
#       <td id="T_5dc70_row4_col1" class="data row4 col1" >0.130000</td>
#       <td id="T_5dc70_row4_col2" class="data row4 col2" >0.200000</td>
#       <td id="T_5dc70_row4_col3" class="data row4 col3" >0.130000</td>
#       <td id="T_5dc70_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_5dc70_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_5dc70_row4_col6" class="data row4 col6" >0.140000</td>
#       <td id="T_5dc70_row4_col7" class="data row4 col7" >0.070000</td>
#     </tr>
#     <tr>
#       <th id="T_5dc70_level0_row5" class="row_heading level0 row5" >accidentedetrabajo</th>
#       <td id="T_5dc70_row5_col0" class="data row5 col0" >0.060000</td>
#       <td id="T_5dc70_row5_col1" class="data row5 col1" >-0.010000</td>
#       <td id="T_5dc70_row5_col2" class="data row5 col2" >-0.000000</td>
#       <td id="T_5dc70_row5_col3" class="data row5 col3" >-0.010000</td>
#       <td id="T_5dc70_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_5dc70_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_5dc70_row5_col6" class="data row5 col6" >-0.150000</td>
#       <td id="T_5dc70_row5_col7" class="data row5 col7" >0.040000</td>
#     </tr>
#     <tr>
#       <th id="T_5dc7

# %%
pearson.style.background_gradient(cmap="viridis")
# Out:
# <style type="text/css">
# #T_e564c_row0_col0, #T_e564c_row1_col1, #T_e564c_row2_col2, #T_e564c_row3_col3, #T_e564c_row4_col4, #T_e564c_row5_col5, #T_e564c_row6_col6, #T_e564c_row7_col7 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_e564c_row0_col1 {
#   background-color: #472a7a;
#   color: #f1f1f1;
# }
# #T_e564c_row0_col2, #T_e564c_row0_col3, #T_e564c_row0_col4, #T_e564c_row0_col6, #T_e564c_row5_col1, #T_e564c_row6_col0, #T_e564c_row6_col5, #T_e564c_row6_col7, #T_e564c_row7_col1 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_e564c_row0_col5, #T_e564c_row2_col0 {
#   background-color: #433e85;
#   color: #f1f1f1;
# }
# #T_e564c_row0_col7 {
#   background-color: #481f70;
#   color: #f1f1f1;
# }
# #T_e564c_row1_col0 {
#   background-color: #2e6f8e;
#   color: #f1f1f1;
# }
# #T_e564c_row1_col2, #T_e564c_row2_col3 {
#   background-color: #27808e;
#   color: #f1f1f1;
# }
# #T_e564c_row1_col3 {
#   background-color: #2e6d8e;
#   color: #f1f1f1;
# }
# #T_e564c_row1_col4, #T_e564c_row3_col4, #T_e564c_row4_col0 {
#   background-color: #404688;
#   color: #f1f1f1;
# }
# #T_e564c_row1_col5, #T_e564c_row3_col5, #T_e564c_row4_col7, #T_e564c_row5_col2 {
#   background-color: #472c7a;
#   color: #f1f1f1;
# }
# #T_e564c_row1_col6 {
#   background-color: #365c8d;
#   color: #f1f1f1;
# }
# #T_e564c_row1_col7, #T_e564c_row2_col7 {
#   background-color: #471365;
#   color: #f1f1f1;
# }
# #T_e564c_row2_col1 {
#   background-color: #2e6e8e;
#   color: #f1f1f1;
# }
# #T_e564c_row2_col4 {
#   background-color: #38588c;
#   color: #f1f1f1;
# }
# #T_e564c_row2_col5, #T_e564c_row4_col5 {
#   background-color: #472e7c;
#   color: #f1f1f1;
# }
# #T_e564c_row2_col6 {
#   background-color: #355e8d;
#   color: #f1f1f1;
# }
# #T_e564c_row3_col0 {
#   background-color: #39568c;
#   color: #f1f1f1;
# }
# #T_e564c_row3_col1 {
#   background-color: #2f6b8e;
#   color: #f1f1f1;
# }
# #T_e564c_row3_col2 {
#   background-color: #218e8d;
#   color: #f1f1f1;
# }
# #T_e564c_row3_col6 {
#   background-color: #31678e;
#   color: #f1f1f1;
# }
# #T_e564c_row3_col7 {
#   background-color: #481668;
#   color: #f1f1f1;
# }
# #T_e564c_row4_col1, #T_e564c_row6_col2 {
#   background-color: #46307e;
#   color: #f1f1f1;
# }
# #T_e564c_row4_col2 {
#   background-color: #355f8d;
#   color: #f1f1f1;
# }
# #T_e564c_row4_col3 {
#   background-color: #46337f;
#   color: #f1f1f1;
# }
# #T_e564c_row4_col6 {
#   background-color: #2c738e;
#   color: #f1f1f1;
# }
# #T_e564c_row5_col0 {
#   background-color: #32658e;
#   color: #f1f1f1;
# }
# #T_e564c_row5_col3 {
#   background-color: #450457;
#   color: #f1f1f1;
# }
# #T_e564c_row5_col4 {
#   background-color: #482173;
#   color: #f1f1f1;
# }
# #T_e564c_row5_col6 {
#   background-color: #443b84;
#   color: #f1f1f1;
# }
# #T_e564c_row5_col7 {
#   background-color: #482374;
#   color: #f1f1f1;
# }
# #T_e564c_row6_col1, #T_e564c_row7_col3 {
#   background-color: #46085c;
#   color: #f1f1f1;
# }
# #T_e564c_row6_col3 {
#   background-color: #482071;
#   color: #f1f1f1;
# }
# #T_e564c_row6_col4 {
#   background-color: #3f4889;
#   color: #f1f1f1;
# }
# #T_e564c_row7_col0 {
#   background-color: #34608d;
#   color: #f1f1f1;
# }
# #T_e564c_row7_col2 {
#   background-color: #482979;
#   color: #f1f1f1;
# }
# #T_e564c_row7_col4 {
#   background-color: #453581;
#   color: #f1f1f1;
# }
# #T_e564c_row7_col5 {
#   background-color: #443983;
#   color: #f1f1f1;
# }
# #T_e564c_row7_col6 {
#   background-color: #3d4e8a;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e564c_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >niveldesatisfaccion</th>
#       <th class="col_heading level0 col1" >ultimaevaluacion</th>
#       <th class="col_heading level0 col2" >numerosdeproyectos</th>
#       <th class="col_heading level0 col3" >horasmensualespromedio</th>
#       <th class="col_heading level0 col4" >tiempoenlaempresa</th>
#       <th class="col_heading level0 col5" >accidentedetrabajo</th>
#       <th class="col_heading level0 col6" >abandono</th>
#       <th class="col_heading level0 col7" >promocionultimos5años</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e564c_level0_row0" class="row_heading level0 row0" >niveldesatisfaccion</th>
#       <td id="T_e564c_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_e564c_row0_col1" class="data row0 col1" >0.110000</td>
#       <td id="T_e564c_row0_col2" class="data row0 col2" >-0.140000</td>
#       <td id="T_e564c_row0_col3" class="data row0 col3" >-0.020000</td>
#       <td id="T_e564c_row0_col4" class="data row0 col4" >-0.100000</td>
#       <td id="T_e564c_row0_col5" class="data row0 col5" >0.060000</td>
#       <td id="T_e564c_row0_col6" class="data row0 col6" >-0.390000</td>
#       <td id="T_e564c_row0_col7" class="data row0 col7" >0.030000</td>
#     </tr>
#     <tr>
#       <th id="T_e564c_level0_row1" class="row_heading level0 row1" >ultimaevaluacion</th>
#       <td id="T_e564c_row1_col0" class="data row1 col0" >0.110000</td>
#       <td id="T_e564c_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_e564c_row1_col2" class="data row1 col2" >0.350000</td>
#       <td id="T_e564c_row1_col3" class="data row1 col3" >0.340000</td>
#       <td id="T_e564c_row1_col4" class="data row1 col4" >0.130000</td>
#       <td id="T_e564c_row1_col5" class="data row1 col5" >-0.010000</td>
#       <td id="T_e564c_row1_col6" class="data row1 col6" >0.010000</td>
#       <td id="T_e564c_row1_col7" class="data row1 col7" >-0.010000</td>
#     </tr>
#     <tr>
#       <th id="T_e564c_level0_row2" class="row_heading level0 row2" >numerosdeproyectos</th>
#       <td id="T_e564c_row2_col0" class="data row2 col0" >-0.140000</td>
#       <td id="T_e564c_row2_col1" class="data row2 col1" >0.350000</td>
#       <td id="T_e564c_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_e564c_row2_col3" class="data row2 col3" >0.420000</td>
#       <td id="T_e564c_row2_col4" class="data row2 col4" >0.200000</td>
#       <td id="T_e564c_row2_col5" class="data row2 col5" >-0.000000</td>
#       <td id="T_e564c_row2_col6" class="data row2 col6" >0.020000</td>
#       <td id="T_e564c_row2_col7" class="data row2 col7" >-0.010000</td>
#     </tr>
#     <tr>
#       <th id="T_e564c_level0_row3" class="row_heading level0 row3" >horasmensualespromedio</th>
#       <td id="T_e564c_row3_col0" class="data row3 col0" >-0.020000</td>
#       <td id="T_e564c_row3_col1" class="data row3 col1" >0.340000</td>
#       <td id="T_e564c_row3_col2" class="data row3 col2" >0.420000</td>
#       <td id="T_e564c_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_e564c_row3_col4" class="data row3 col4" >0.130000</td>
#       <td id="T_e564c_row3_col5" class="data row3 col5" >-0.010000</td>
#       <td id="T_e564c_row3_col6" class="data row3 col6" >0.070000</td>
#       <td id="T_e564c_row3_col7" class="data row3 col7" >-0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e564c_level0_row4" class="row_heading level0 row4" >tiempoenlaempresa</th>
#       <td id="T_e564c_row4_col0" class="data row4 col0" >-0.100000</td>
#       <td id="T_e564c_row4_col1" class="data row4 col1" >0.130000</td>
#       <td id="T_e564c_row4_col2" class="data row4 col2" >0.200000</td>
#       <td id="T_e564c_row4_col3" class="data row4 col3" >0.130000</td>
#       <td id="T_e564c_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_e564c_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_e564c_row4_col6" class="data row4 col6" >0.140000</td>
#       <td id="T_e564c_row4_col7" class="data row4 col7" >0.070000</td>
#     </tr>
#     <tr>
#       <th id="T_e564c_level0_row5" class="row_heading level0 row5" >accidentedetrabajo</th>
#       <td id="T_e564c_row5_col0" class="data row5 col0" >0.060000</td>
#       <td id="T_e564c_row5_col1" class="data row5 col1" >-0.010000</td>
#       <td id="T_e564c_row5_col2" class="data row5 col2" >-0.000000</td>
#       <td id="T_e564c_row5_col3" class="data row5 col3" >-0.010000</td>
#       <td id="T_e564c_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_e564c_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_e564c_row5_col6" class="data row5 col6" >-0.150000</td>
#       <td id="T_e564c_row5_col7" class="data row5 col7" >0.040000</td>
#     </tr>
#     <tr>
#       <th id="T_e564

# %%
pearson.style.background_gradient(cmap="copper")
# Out:
# <style type="text/css">
# #T_f1048_row0_col0, #T_f1048_row1_col1, #T_f1048_row2_col2, #T_f1048_row3_col3, #T_f1048_row4_col4, #T_f1048_row5_col5, #T_f1048_row6_col6, #T_f1048_row7_col7 {
#   background-color: #ffc77f;
#   color: #000000;
# }
# #T_f1048_row0_col1 {
#   background-color: #25170f;
#   color: #f1f1f1;
# }
# #T_f1048_row0_col2, #T_f1048_row0_col3, #T_f1048_row0_col4, #T_f1048_row0_col6, #T_f1048_row5_col1, #T_f1048_row6_col0, #T_f1048_row6_col5, #T_f1048_row6_col7, #T_f1048_row7_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_f1048_row0_col5, #T_f1048_row2_col0 {
#   background-color: #392417;
#   color: #f1f1f1;
# }
# #T_f1048_row0_col7 {
#   background-color: #1a100a;
#   color: #f1f1f1;
# }
# #T_f1048_row1_col0 {
#   background-color: #72482e;
#   color: #f1f1f1;
# }
# #T_f1048_row1_col2, #T_f1048_row2_col3 {
#   background-color: #885637;
#   color: #f1f1f1;
# }
# #T_f1048_row1_col3 {
#   background-color: #6f462d;
#   color: #f1f1f1;
# }
# #T_f1048_row1_col4, #T_f1048_row3_col4, #T_f1048_row4_col0 {
#   background-color: #41291a;
#   color: #f1f1f1;
# }
# #T_f1048_row1_col5, #T_f1048_row3_col5, #T_f1048_row4_col7, #T_f1048_row5_col2 {
#   background-color: #26180f;
#   color: #f1f1f1;
# }
# #T_f1048_row1_col6 {
#   background-color: #5a3924;
#   color: #f1f1f1;
# }
# #T_f1048_row1_col7, #T_f1048_row2_col7 {
#   background-color: #0f0906;
#   color: #f1f1f1;
# }
# #T_f1048_row2_col1 {
#   background-color: #70472d;
#   color: #f1f1f1;
# }
# #T_f1048_row2_col4 {
#   background-color: #553622;
#   color: #f1f1f1;
# }
# #T_f1048_row2_col5, #T_f1048_row4_col5 {
#   background-color: #291a10;
#   color: #f1f1f1;
# }
# #T_f1048_row2_col6 {
#   background-color: #5d3b25;
#   color: #f1f1f1;
# }
# #T_f1048_row3_col0 {
#   background-color: #543522;
#   color: #f1f1f1;
# }
# #T_f1048_row3_col1 {
#   background-color: #6d452c;
#   color: #f1f1f1;
# }
# #T_f1048_row3_col2 {
#   background-color: #9a623e;
#   color: #f1f1f1;
# }
# #T_f1048_row3_col6 {
#   background-color: #68422a;
#   color: #f1f1f1;
# }
# #T_f1048_row3_col7 {
#   background-color: #110b07;
#   color: #f1f1f1;
# }
# #T_f1048_row4_col1, #T_f1048_row6_col2 {
#   background-color: #2b1b11;
#   color: #f1f1f1;
# }
# #T_f1048_row4_col2 {
#   background-color: #5e3b26;
#   color: #f1f1f1;
# }
# #T_f1048_row4_col3 {
#   background-color: #2e1d12;
#   color: #f1f1f1;
# }
# #T_f1048_row4_col6 {
#   background-color: #784c30;
#   color: #f1f1f1;
# }
# #T_f1048_row5_col0 {
#   background-color: #654029;
#   color: #f1f1f1;
# }
# #T_f1048_row5_col3 {
#   background-color: #020201;
#   color: #f1f1f1;
# }
# #T_f1048_row5_col4 {
#   background-color: #1c120b;
#   color: #f1f1f1;
# }
# #T_f1048_row5_col6 {
#   background-color: #362216;
#   color: #f1f1f1;
# }
# #T_f1048_row5_col7 {
#   background-color: #1e130c;
#   color: #f1f1f1;
# }
# #T_f1048_row6_col1, #T_f1048_row7_col3 {
#   background-color: #060402;
#   color: #f1f1f1;
# }
# #T_f1048_row6_col3 {
#   background-color: #1b110b;
#   color: #f1f1f1;
# }
# #T_f1048_row6_col4 {
#   background-color: #442b1b;
#   color: #f1f1f1;
# }
# #T_f1048_row7_col0 {
#   background-color: #5f3c26;
#   color: #f1f1f1;
# }
# #T_f1048_row7_col2 {
#   background-color: #24170e;
#   color: #f1f1f1;
# }
# #T_f1048_row7_col4 {
#   background-color: #301e13;
#   color: #f1f1f1;
# }
# #T_f1048_row7_col5 {
#   background-color: #342115;
#   color: #f1f1f1;
# }
# #T_f1048_row7_col6 {
#   background-color: #4a2f1e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f1048_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >niveldesatisfaccion</th>
#       <th class="col_heading level0 col1" >ultimaevaluacion</th>
#       <th class="col_heading level0 col2" >numerosdeproyectos</th>
#       <th class="col_heading level0 col3" >horasmensualespromedio</th>
#       <th class="col_heading level0 col4" >tiempoenlaempresa</th>
#       <th class="col_heading level0 col5" >accidentedetrabajo</th>
#       <th class="col_heading level0 col6" >abandono</th>
#       <th class="col_heading level0 col7" >promocionultimos5años</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f1048_level0_row0" class="row_heading level0 row0" >niveldesatisfaccion</th>
#       <td id="T_f1048_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_f1048_row0_col1" class="data row0 col1" >0.110000</td>
#       <td id="T_f1048_row0_col2" class="data row0 col2" >-0.140000</td>
#       <td id="T_f1048_row0_col3" class="data row0 col3" >-0.020000</td>
#       <td id="T_f1048_row0_col4" class="data row0 col4" >-0.100000</td>
#       <td id="T_f1048_row0_col5" class="data row0 col5" >0.060000</td>
#       <td id="T_f1048_row0_col6" class="data row0 col6" >-0.390000</td>
#       <td id="T_f1048_row0_col7" class="data row0 col7" >0.030000</td>
#     </tr>
#     <tr>
#       <th id="T_f1048_level0_row1" class="row_heading level0 row1" >ultimaevaluacion</th>
#       <td id="T_f1048_row1_col0" class="data row1 col0" >0.110000</td>
#       <td id="T_f1048_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_f1048_row1_col2" class="data row1 col2" >0.350000</td>
#       <td id="T_f1048_row1_col3" class="data row1 col3" >0.340000</td>
#       <td id="T_f1048_row1_col4" class="data row1 col4" >0.130000</td>
#       <td id="T_f1048_row1_col5" class="data row1 col5" >-0.010000</td>
#       <td id="T_f1048_row1_col6" class="data row1 col6" >0.010000</td>
#       <td id="T_f1048_row1_col7" class="data row1 col7" >-0.010000</td>
#     </tr>
#     <tr>
#       <th id="T_f1048_level0_row2" class="row_heading level0 row2" >numerosdeproyectos</th>
#       <td id="T_f1048_row2_col0" class="data row2 col0" >-0.140000</td>
#       <td id="T_f1048_row2_col1" class="data row2 col1" >0.350000</td>
#       <td id="T_f1048_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_f1048_row2_col3" class="data row2 col3" >0.420000</td>
#       <td id="T_f1048_row2_col4" class="data row2 col4" >0.200000</td>
#       <td id="T_f1048_row2_col5" class="data row2 col5" >-0.000000</td>
#       <td id="T_f1048_row2_col6" class="data row2 col6" >0.020000</td>
#       <td id="T_f1048_row2_col7" class="data row2 col7" >-0.010000</td>
#     </tr>
#     <tr>
#       <th id="T_f1048_level0_row3" class="row_heading level0 row3" >horasmensualespromedio</th>
#       <td id="T_f1048_row3_col0" class="data row3 col0" >-0.020000</td>
#       <td id="T_f1048_row3_col1" class="data row3 col1" >0.340000</td>
#       <td id="T_f1048_row3_col2" class="data row3 col2" >0.420000</td>
#       <td id="T_f1048_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_f1048_row3_col4" class="data row3 col4" >0.130000</td>
#       <td id="T_f1048_row3_col5" class="data row3 col5" >-0.010000</td>
#       <td id="T_f1048_row3_col6" class="data row3 col6" >0.070000</td>
#       <td id="T_f1048_row3_col7" class="data row3 col7" >-0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f1048_level0_row4" class="row_heading level0 row4" >tiempoenlaempresa</th>
#       <td id="T_f1048_row4_col0" class="data row4 col0" >-0.100000</td>
#       <td id="T_f1048_row4_col1" class="data row4 col1" >0.130000</td>
#       <td id="T_f1048_row4_col2" class="data row4 col2" >0.200000</td>
#       <td id="T_f1048_row4_col3" class="data row4 col3" >0.130000</td>
#       <td id="T_f1048_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_f1048_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_f1048_row4_col6" class="data row4 col6" >0.140000</td>
#       <td id="T_f1048_row4_col7" class="data row4 col7" >0.070000</td>
#     </tr>
#     <tr>
#       <th id="T_f1048_level0_row5" class="row_heading level0 row5" >accidentedetrabajo</th>
#       <td id="T_f1048_row5_col0" class="data row5 col0" >0.060000</td>
#       <td id="T_f1048_row5_col1" class="data row5 col1" >-0.010000</td>
#       <td id="T_f1048_row5_col2" class="data row5 col2" >-0.000000</td>
#       <td id="T_f1048_row5_col3" class="data row5 col3" >-0.010000</td>
#       <td id="T_f1048_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_f1048_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_f1048_row5_col6" class="data row5 col6" >-0.150000</td>
#       <td id="T_f1048_row5_col7" class="data row5 col7" >0.040000</td>
#     </tr>
#     <tr>
#       <th id="T_f104

# %% [markdown]
# ## **<font color="RoyalBlue">Matriz de correlación** - Coeficiente estándar = método Spearman

# %%
spearman = analisis.corr(method="spearman").round(2)

# %%
spearman
# Out:
#                         niveldesatisfaccion  ultimaevaluacion  \
# niveldesatisfaccion                    1.00              0.16
# ultimaevaluacion                       0.16              1.00
# numerosdeproyectos                     0.01              0.35
# horasmensualespromedio                 0.06              0.34
# tiempoenlaempresa                     -0.14              0.16
# accidentedetrabajo                     0.06             -0.01
# abandono                              -0.37             -0.00
# promocionultimos5años                  0.02             -0.01
#
#                         numerosdeproyectos  horasmensualespromedio  \
# niveldesatisfaccion                   0.01                    0.06
# ultimaevaluacion                      0.35                    0.34
# numerosdeproyectos                    1.00                    0.40
# horasmensualespromedio                0.40                    1.00
# tiempoenlaempresa                     0.25                    0.17
# accidentedetrabajo                    0.00                   -0.01
# abandono                             -0.02                    0.05
# promocionultimos5años                -0.00                   -0.00
#
#                         tiempoenlaempresa  accidentedetrabajo  abandono  \
# niveldesatisfaccion                 -0.14                0.06     -0.37
# ultimaevaluacion                     0.16               -0.01     -0.00
# numerosdeproyectos                   0.25                0.00     -0.02
# horasmensualespromedio               0.17               -0.01      0.05
# tiempoenlaempresa                    1.00               -0.03      0.27
# accidentedetrabajo                  -0.03                1.00     -0.15
# abandono                             0.27               -0.15      1.00
# promocionultimos5años                0.04                0.04     -0.06
#
#                         promocionultimos5años
# niveldesatisfaccion                      0.02
# ultimaevaluacion                        -0.01
# numerosdeproyectos                      -0.00
# horasmensualespromedio                  -0.00
# tiempoenlaempresa                        0.04
# accidentedetrabajo                       0.04
# abandono                                -0.06
# promocionultimos5años                    1.00

# %%
px.imshow(spearman,
          title = "Matriz de correlacion",
          text_auto = True, 
          template = "seaborn",
          labels={"color":"Coeficiente"})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="129dd630-77b4-4b12-9f7d-416009212ba0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("129dd630-77b4-4b12-9f7d-416009212ba0")) {                    Plotly.newPlot(                        "129dd630-77b4-4b12-9f7d-416009212ba0",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","x":["niveldesatisfaccion","ultimaevaluacion","numerosdeproyectos","horasmensualespromedio","tiempoenlaempresa","accidentedetrabajo","abandono","promocionultimos5a\u00f1os"],"y":["niveldesatisfaccion","ultimaevaluacion","numerosdeproyectos","horasmensualespromedio","tiempoenlaempresa","accidentedetrabajo","abandono","promocionultimos5a\u00f1os"],"z":[[1.0,0.16,0.01,0.06,-0.14,0.06,-0.37,0.02],[0.16,1.0,0.35,0.34,0.16,-0.01,-0.0,-0.01],[0.01,0.35,1.0,0.4,0.25,0.0,-0.02,-0.0],[0.06,0.34,0.4,1.0,0.17,-0.01,0.05,-0.0],[-0.14,0.16,0.25,0.17,1.0,-0.03,0.27,0.04],[0.06,-0.01,0.0,-0.01,-0.03,1.0,-0.15,0.04],[-0.37,-0.0,-0.02,0.05,0.27,-0.15,1.0,-0.06],[0.02,-0.01,-0.0,-0.0,0.04,0.04,-0.06,1.0]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}<br>y: %{y}<br>Coeficiente: %{z}<extra></extra>"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(234,234,242)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"rgb(234,234,242)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"colorscale":[[0.0,"rgb(2,4,25)"],[0.06274509803921569,"rgb(24,15,41)"],[0.12549019607843137,"rgb(47,23,57)"],[0.18823529411764706,"rgb(71,28,72)"],[0.25098039215686274,"rgb(97,30,82)"],[0.3137254901960784,"rgb(123,30,89)"],[0.3764705882352941,"rgb(150,27,91)"],[0.4392156862745098,"rgb(177,22,88)"],[0.5019607843137255,"rgb(203,26,79)"],[0.5647058823529412,"rgb(223,47,67)"],[0.6274509803921569,"rgb(236,76,61)"],[0.6901960784313725,"rgb(242,107,73)"],[0.7529411764705882,"rgb(244,135,95)"],[0.8156862745098039,"rgb(245,162,122)"],[0.8784313725490196,"rgb(246,188,153)"],[0.9411764705882353,"rgb(247,212,187)"],[1.0,"rgb(250,234,220)"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"colorscale":[[0.0,"rgb(2,4,25)"],[0.06274509803921569,"rgb(24,15,41)"],[0.12549019607843137,"rgb(47,23,57)"],[0.18823529411764706,"rgb(71,28,72)"],[0.25098039215686274,"rgb(97,30,82)"],[0.3137254901960784,"rgb(123,30,89)"],[0.3764705882352941,"rgb(150,27,91)"],[0.4392156862745098,"rgb(177,22,88)"],[0.5019607843137255,"rgb(203,26,79)"],[0.5647058823529412,"rgb(223,47,67)"],[0.6274509803921569,"rgb(236,76,61)"],[0.6901960784313725,"rgb(242,107,73)"],[0.7529411764705882,"rgb(244,135,95)"],[0.8156862745098039,"rgb(245,162,122)"],[0.8784313725490196,"rgb(246,188,153)"],[0.9411764705882353,"rgb(247,212,187)"],[1.0,"rgb(250,234,220)"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth": ...

# %% [markdown]
# ## **<font color="RoyalBlue">Matriz de correlación** - Coeficiente estándar = método Kendall

# %%
kendall = analisis.corr(method="kendall").round(2)

# %%
kendall
# Out:
#                         niveldesatisfaccion  ultimaevaluacion  \
# niveldesatisfaccion                    1.00              0.11
# ultimaevaluacion                       0.11              1.00
# numerosdeproyectos                     0.02              0.27
# horasmensualespromedio                 0.05              0.24
# tiempoenlaempresa                     -0.11              0.12
# accidentedetrabajo                     0.05             -0.00
# abandono                              -0.30             -0.00
# promocionultimos5años                  0.02             -0.01
#
#                         numerosdeproyectos  horasmensualespromedio  \
# niveldesatisfaccion                   0.02                    0.05
# ultimaevaluacion                      0.27                    0.24
# numerosdeproyectos                    1.00                    0.31
# horasmensualespromedio                0.31                    1.00
# tiempoenlaempresa                     0.20                    0.12
# accidentedetrabajo                    0.00                   -0.00
# abandono                             -0.02                    0.04
# promocionultimos5años                -0.00                   -0.00
#
#                         tiempoenlaempresa  accidentedetrabajo  abandono  \
# niveldesatisfaccion                 -0.11                0.05     -0.30
# ultimaevaluacion                     0.12               -0.00     -0.00
# numerosdeproyectos                   0.20                0.00     -0.02
# horasmensualespromedio               0.12               -0.00      0.04
# tiempoenlaempresa                    1.00               -0.02      0.24
# accidentedetrabajo                  -0.02                1.00     -0.15
# abandono                             0.24               -0.15      1.00
# promocionultimos5años                0.03                0.04     -0.06
#
#                         promocionultimos5años
# niveldesatisfaccion                      0.02
# ultimaevaluacion                        -0.01
# numerosdeproyectos                      -0.00
# horasmensualespromedio                  -0.00
# tiempoenlaempresa                        0.03
# accidentedetrabajo                       0.04
# abandono                                -0.06
# promocionultimos5años                    1.00

# %%
px.imshow(kendall,
          title = "Matriz de correlacion",
          text_auto = True, 
          template = "seaborn",
          labels={"color":"Coeficiente"})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b69ae351-ca93-4aa5-ae62-e508b210da8a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b69ae351-ca93-4aa5-ae62-e508b210da8a")) {                    Plotly.newPlot(                        "b69ae351-ca93-4aa5-ae62-e508b210da8a",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","x":["niveldesatisfaccion","ultimaevaluacion","numerosdeproyectos","horasmensualespromedio","tiempoenlaempresa","accidentedetrabajo","abandono","promocionultimos5a\u00f1os"],"y":["niveldesatisfaccion","ultimaevaluacion","numerosdeproyectos","horasmensualespromedio","tiempoenlaempresa","accidentedetrabajo","abandono","promocionultimos5a\u00f1os"],"z":[[1.0,0.11,0.02,0.05,-0.11,0.05,-0.3,0.02],[0.11,1.0,0.27,0.24,0.12,-0.0,-0.0,-0.01],[0.02,0.27,1.0,0.31,0.2,0.0,-0.02,-0.0],[0.05,0.24,0.31,1.0,0.12,-0.0,0.04,-0.0],[-0.11,0.12,0.2,0.12,1.0,-0.02,0.24,0.03],[0.05,-0.0,0.0,-0.0,-0.02,1.0,-0.15,0.04],[-0.3,-0.0,-0.02,0.04,0.24,-0.15,1.0,-0.06],[0.02,-0.01,-0.0,-0.0,0.03,0.04,-0.06,1.0]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}<br>y: %{y}<br>Coeficiente: %{z}<extra></extra>"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(234,234,242)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"rgb(234,234,242)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"colorscale":[[0.0,"rgb(2,4,25)"],[0.06274509803921569,"rgb(24,15,41)"],[0.12549019607843137,"rgb(47,23,57)"],[0.18823529411764706,"rgb(71,28,72)"],[0.25098039215686274,"rgb(97,30,82)"],[0.3137254901960784,"rgb(123,30,89)"],[0.3764705882352941,"rgb(150,27,91)"],[0.4392156862745098,"rgb(177,22,88)"],[0.5019607843137255,"rgb(203,26,79)"],[0.5647058823529412,"rgb(223,47,67)"],[0.6274509803921569,"rgb(236,76,61)"],[0.6901960784313725,"rgb(242,107,73)"],[0.7529411764705882,"rgb(244,135,95)"],[0.8156862745098039,"rgb(245,162,122)"],[0.8784313725490196,"rgb(246,188,153)"],[0.9411764705882353,"rgb(247,212,187)"],[1.0,"rgb(250,234,220)"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"colorscale":[[0.0,"rgb(2,4,25)"],[0.06274509803921569,"rgb(24,15,41)"],[0.12549019607843137,"rgb(47,23,57)"],[0.18823529411764706,"rgb(71,28,72)"],[0.25098039215686274,"rgb(97,30,82)"],[0.3137254901960784,"rgb(123,30,89)"],[0.3764705882352941,"rgb(150,27,91)"],[0.4392156862745098,"rgb(177,22,88)"],[0.5019607843137255,"rgb(203,26,79)"],[0.5647058823529412,"rgb(223,47,67)"],[0.6274509803921569,"rgb(236,76,61)"],[0.6901960784313725,"rgb(242,107,73)"],[0.7529411764705882,"rgb(244,135,95)"],[0.8156862745098039,"rgb(245,162,122)"],[0.8784313725490196,"rgb(246,188,153)"],[0.9411764705882353,"rgb(247,212,187)"],[1.0,"rgb(250,234,220)"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"tic ...

# %% [markdown]
# ---
# <p>
# <font color="RoyalBlue">
#
# 💙 **Hemos llegado al fin de este cuaderno, felicitaciones estamos avanzando en el Analisis Exploratorio de los Datos, ahora a seguir en el proximo cuaderno...**
# </font>
# </p>
#
# ---

# %% [markdown]
# # 😀
